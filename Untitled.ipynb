# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
test = pd.read_csv("test.csv")

# %%
train = pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.shape
# Out:
# (891, 12)

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
train['died'] = 1 - train['Survived']

# %%
train['died'].sum()
# Out:
# 549

# %%
train.Survived.sum()
# Out:
# 342

# %%
train.groupby('Sex').agg('sum')[['Survived', 'died']].plot(kind='bar',
                                                           figsize=(10, 5),
                                                           stacked=True)
# Out:
# <AxesSubplot:xlabel='Sex'>

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  died
# 0      0         A/5 21171   7.2500   NaN        S     1
# 1      0          PC 17599  71.2833   C85        C     0
# 2      0  STON/O2. 3101282   7.9250   NaN        S     0
# 3      0            113803  53.1000  C123        S     0
# ...

# %%
figure = plt.figure(figsize = (16,7))
plt.hist([train[train['Survived'] == 1]['Fare'], train[train['Survived'] == 0]['Fare']], stacked = True, bins = 50, label = ['Survived','Dead'])
plt.xlabel('Fare')
plt.ylabel('Number of passenger')
plt.legend()
plt.show()

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  died
# 0      0         A/5 21171   7.2500   NaN        S     1
# 1      0          PC 17599  71.2833   C85        C     0
# 2      0  STON/O2. 3101282   7.9250   NaN        S     0
# 3      0            113803  53.1000  C123        S     0
# ...

# %%
df1 = train.drop(['PassengerId','Ticket','Cabin','died'], axis=1)

# %%
df1.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Embarked
# 0    male  22.0      1      0   7.2500        S
# 1  female  38.0      1      0  71.2833        C
# 2  female  26.0      0      0   7.9250        S
# 3  female  35.0      1      0  53.1000        S
# 4    male  35.0      0      0   8.0500        S

# %%
df1.isnull()
# Out:
#      Survived  Pclass   Name    Sex    Age  SibSp  Parch   Fare  Embarked
# 0       False   False  False  False  False  False  False  False     False
# 1       False   False  False  False  False  False  False  False     False
# 2       False   False  False  False  False  False  False  False     False
# 3       False   False  False  False  False  False  False  False     False
# 4       False   False  False  False  False  False  False  False     False
# ..        ...     ...    ...    ...    ...    ...    ...    ...       ...
# 886     False   False  False  False  False  False  False  False     False
# 887     False   False  False  False  False  False  False  False     False
# 888     False   False  False  False   True  False  False  False     False
# 889     False   False  False  False  False  False  False  False     False
# 890     False   False  False  False  False  False  False  False     False
#
# [891 rows x 9 columns]

# %%
df1.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
df1.isnull().sum().sum()
# Out:
# 179

# %%
df1.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Embarked
# 0    male  22.0      1      0   7.2500        S
# 1  female  38.0      1      0  71.2833        C
# 2  female  26.0      0      0   7.9250        S
# 3  female  35.0      1      0  53.1000        S
# 4    male  35.0      0      0   8.0500        S

# %%
df1.Embarked = df1.Embarked.map({'S': 0, 'C' : 1, 'nan' : 'NAN'})

# %%
df1.head(10)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
# 5         0       3                                   Moran, Mr. James
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
# 8         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9         1       2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       Sex   Age  SibSp  Parch     Fare Embarked
# 0    male  22.0      1      0   7.2500        0
# 1  female  38.0      1      0  71.2833        1
# ...

# %%
mean_age_men = df1[df1['Sex'] =='male']['Age'].mean()

# %%
mean_age_men
# Out:
# 30.72664459161148

# %%
mean_age_women = df1[df1['Sex'] == 'female']['Age'].mean()

# %%
mean_age_women
# Out:
# 27.915708812260537

# %%
df1.loc[(df1.Age.isnull()) & (df1['Sex'] == 'male'),'Age'] = mean_age_men
df1.loc[(df1.Age.isnull()) & (df1['Sex'] == 'female'),'Age'] = mean_age_women

# %%
df1.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Embarked  Avg
# 0    male  22.0      1      0   7.2500        0  NaN
# 1  female  38.0      1      0  71.2833        1  NaN
# 2  female  26.0      0      0   7.9250        0  NaN
# 3  female  35.0      1      0  53.1000        0  NaN
# 4    male  35.0      0      0   8.0500        0  NaN

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df1.head(10)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
# 5         0       3                                   Moran, Mr. James
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
# 8         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9         1       2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       Sex        Age  SibSp  Parch     Fare Embarked        Avg
# 0    male  22.000000      1      0   7.2500        0        NaN
# ...

# %%
df1.loc[(df1.Age.isnull()) & (df1['Sex'] == 'male'),'Age'] = mean_age_men
df1.loc[(df1.Age.isnull()) & (df1['Sex'] == 'female'),'Age'] = mean_age_women

# %%
df1.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Fare          0
# Embarked     79
# Avg         714
# dtype: int64

# %%
df1.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Embarked  Avg
# 0    male  22.0      1      0   7.2500        0  NaN
# 1  female  38.0      1      0  71.2833        1  NaN
# 2  female  26.0      0      0   7.9250        0  NaN
# 3  female  35.0      1      0  53.1000        0  NaN
# 4    male  35.0      0      0   8.0500        0  NaN

# %%
df1 = df1.drop(['Avg'], axis=1)

# %%
df1.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Embarked
# 0    male  22.0      1      0   7.2500        0
# 1  female  38.0      1      0  71.2833        1
# 2  female  26.0      0      0   7.9250        0
# 3  female  35.0      1      0  53.1000        0
# 4    male  35.0      0      0   8.0500        0

# %%
df1.isnull().sum()
# Out:
# Survived     0
# Pclass       0
# Name         0
# Sex          0
# Age          0
# SibSp        0
# Parch        0
# Fare         0
# Embarked    79
# dtype: int64

# %%
df1.dropna(inplace = True)

# %%
df1.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df2 = test.drop(['PassengerId','Ticket','Cabin'], axis=1)

# %%
df2.head()
# Out:
#    Pclass                                          Name     Sex   Age  SibSp  \
# 0       3                              Kelly, Mr. James    male  34.5      0
# 1       3              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2       2                     Myles, Mr. Thomas Francis    male  62.0      0
# 3       3                              Wirz, Mr. Albert    male  27.0      0
# 4       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
#
#    Parch     Fare Embarked
# 0      0   7.8292        Q
# 1      0   7.0000        S
# 2      0   9.6875        Q
# 3      0   8.6625        S
# 4      1  12.2875        S

# %%
df2.Embarked = df2.Embarked.map({'S': 0, 'C': 1, 'Q': 2, 'nan': 'NAN'})

# %%
df2.head(10)
# Out:
#    Pclass                                          Name     Sex   Age  SibSp  \
# 0       3                              Kelly, Mr. James    male  34.5      0
# 1       3              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2       2                     Myles, Mr. Thomas Francis    male  62.0      0
# 3       3                              Wirz, Mr. Albert    male  27.0      0
# 4       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 5       3                    Svensson, Mr. Johan Cervin    male  14.0      0
# 6       3                          Connolly, Miss. Kate  female  30.0      0
# 7       2                  Caldwell, Mr. Albert Francis    male  26.0      1
# 8       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 9       3                       Davies, Mr. John Samuel    male  21.0      2
#
#    Parch     Fare Embarked
# 0      0   7.8292        2
# 1      0   7.0000        0
# 2      0   9.6875        2
# ...

# %%
df2.isnull().sum()
# Out:
# Pclass       0
# Name         0
# Sex          0
# Age         86
# SibSp        0
# Parch        0
# Fare         1
# Embarked     0
# dtype: int64

# %%
mean_age_men2 = df2[df2['Sex']=='male']['Age'].mean()
mean_age_women2 = df2[df2['Sex']=='female']['Age'].mean()

# %%
df2.loc[(df2.Age.isnull()) & (df2['Sex'] == 'male')] = mean_age_men2
df2.loc[(df2.Age.isnull()) & (df2['Sex'] == 'female')] = mean_age_women2
df2['Fare'] = df2['Fare'].fillna(df2['Fare'].mean())

# %%
df2.isnull().sum()
# Out:
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
df1.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Embarked
# 0    male  22.0      1      0   7.2500        0
# 1  female  38.0      1      0  71.2833        1
# 2  female  26.0      0      0   7.9250        0
# 3  female  35.0      1      0  53.1000        0
# 4    male  35.0      0      0   8.0500        0

# %%
df2.head()
# Out:
#    Pclass                                          Name     Sex   Age  SibSp  \
# 0     3.0                              Kelly, Mr. James    male  34.5    0.0
# 1     3.0              Wilkes, Mrs. James (Ellen Needs)  female  47.0    1.0
# 2     2.0                     Myles, Mr. Thomas Francis    male  62.0    0.0
# 3     3.0                              Wirz, Mr. Albert    male  27.0    0.0
# 4     3.0  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0    1.0
#
#    Parch     Fare Embarked
# 0    0.0   7.8292        2
# 1    0.0   7.0000        0
# 2    0.0   9.6875        2
# 3    0.0   8.6625        0
# 4    1.0  12.2875        0

# %%
df = pd.merge(df1,df2, how='outer')
# Out:
# /Users/mihir/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py:1219: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation.
#   warnings.warn(
# /Users/mihir/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py:916: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   key_col = Index(lvals).where(~mask_left, rvals)

# %%
df
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0     3.0                            Braund, Mr. Owen Harris
# 1          1.0     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0     3.0                             Heikkinen, Miss. Laina
# 3          1.0     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0     3.0                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1225       NaN     3.0                          Peacock, Miss. Treasteall
# 1226       NaN     1.0    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 1227       NaN     3.0                     Henriksson, Miss. Jenny Lovisa
# 1228       NaN     1.0                       Oliva y Ocana, Dona. Fermina
# 1229       NaN     3.0                       Saether, Mr. Simon Sivertsen
#
#          Sex   Age  SibSp  Parch      Fare Embarked
# ...

# %%
df[(df['Sex']== 'male') & (df['Survived'] == 1.0) & (df['Age'] >= 30)]
# Out:
#      Survived  Pclass                                               Name  \
# 15        1.0     2.0                       Williams, Mr. Charles Eugene
# 19        1.0     2.0                              Beesley, Mr. Lawrence
# 31        1.0     3.0                                   Mamee, Mr. Hanna
# 47        1.0     1.0                                  Woolner, Mr. Hugh
# 56        1.0     3.0                           Moubarek, Master. Gerios
# 65        1.0     3.0                                      Bing, Mr. Lee
# 97        1.0     3.0                             Moss, Mr. Albert Johan
# 170       1.0     1.0      Romaine, Mr. Charles Hallace ("Mr C Rolmane")
# 188       1.0     1.0                                   Blank, Mr. Henry
# 202       1.0     1.0                       Hoyt, Mr. Frederick Maxfield
# 224       1.0     1.0                      Beckwith, Mr. Richard Leonard
# 257       1.0     3.0                            de Mulder, Mr. Theodore
# ...
